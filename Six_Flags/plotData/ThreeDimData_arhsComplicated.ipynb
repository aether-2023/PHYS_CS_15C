# %%
import numpy as np
import imufusion
from scipy.spatial.transform import Rotation as R
import matplotlib.pyplot as plt
import sys
import csv

# %%
sys.path.append("..")
from six_flags_scripts import *

# %% [markdown]
# # 5.30 Six Flags

# %% [markdown]
# ## Gold

# %%
t_interval_list, accel_3d_list, omega_3d_list = get_data('./../testData0530SF/sfgold1')
t_interval_list, accel_3d_list, omega_3d_list = t_interval_list[:16960], accel_3d_list[:16960], omega_3d_list[:16960]
t_list = get_timelist(t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)
accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list[1000:], t_interval_list[1000:])

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list[1000:], velo_list, posi_list, t_list[1000:])

# %%
fig = plt.figure()
x = posi_list[:, 0]
y = posi_list[:, 1]
z = posi_list[:, 2]
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

ax = plt.axes(projection ='3d')
ax.plot3D(x, y, z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()

# %% [markdown]
# ## Superman

# %%
t_interval_list, accel_3d_list, omega_3d_list = get_data('./../testData0530SF/sfsupman')
t_interval_list, accel_3d_list, omega_3d_list = t_interval_list[7000:35000], accel_3d_list[7000:35000], omega_3d_list[7000:35000]

t_list = get_timelist(t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)[:75000]
accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list[1000:], t_interval_list[1000:])

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list[1000:76000], velo_list[:75000], posi_list[:75000], t_list[1000:76000])

# %%
fig = plt.figure()
x = posi_list[:75000, 0]
y = posi_list[:75000, 1]
z = posi_list[:75000, 2]
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

ax = plt.axes(projection ='3d')
ax.plot3D(x, y, z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()

# %% [markdown]
# ## Superman from Jichen's iPhone

# %%
data = np.genfromtxt('./../testData0530SF/Raw Data.csv',delimiter=',')

# %%
plt.figure(figsize=(10,8))
plt.plot(data[:,0], data[:,4])
#plt.yscale('log')
#plt.xlim(30,55)
plt.show()

# %% [markdown]
# ## Viper

# %%
t_interval_list, accel_3d_list, omega_3d_list = get_data('./../testData0530SF/sfviper')
t_interval_list, accel_3d_list, omega_3d_list = t_interval_list[12000:40000], accel_3d_list[12000:40000], omega_3d_list[12000:40000]
t_list = get_timelist(t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)
accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list[1000:], t_interval_list[1000:])

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list[1000:], velo_list, posi_list, t_list[1000:])

# %%
fig = plt.figure()
x = posi_list[1000:, 0]
y = posi_list[1000:, 1]
z = posi_list[1000:, 2]
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

ax = plt.axes(projection ='3d')
ax.plot3D(x, y, z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()

# %% [markdown]
# ## merry-go-round

# %%
t_interval_list, accel_3d_list, omega_3d_list = get_data('./../testData0530SF/sfmgr')
t_interval_list, accel_3d_list, omega_3d_list = t_interval_list[6000:40000], accel_3d_list[6000:40000], omega_3d_list[6000:40000]
t_list = get_timelist(t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)
accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list[1000:], t_interval_list[1000:])

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list[1000:], velo_list, posi_list, t_list[1000:])

# %%
fig = plt.figure()
x = posi_list[1000:, 0]
y = posi_list[1000:, 1]
z = posi_list[1000:, 2]
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

ax = plt.axes(projection ='3d')
ax.plot3D(x, y, z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()

# %% [markdown]
# ## merry-go-round 2

# %%
t_interval_list, accel_3d_list, omega_3d_list = get_data('./../testData0530SF/sfmgr2')
t_interval_list, accel_3d_list, omega_3d_list = t_interval_list[6000:40000], accel_3d_list[6000:40000], omega_3d_list[6000:40000]
t_list = get_timelist(t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)
accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list[1000:], t_interval_list[1000:])

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list[1000:], velo_list, posi_list, t_list[1000:])

# %%
fig = plt.figure()
x = posi_list[1000:, 0]
y = posi_list[1000:, 1]
z = posi_list[1000:, 2]
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

ax = plt.axes(projection ='3d')
ax.plot3D(x, y, z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()

# %% [markdown]
# ## Viper2

# %%
t_interval_list, accel_3d_list, omega_3d_list = get_data('./../testData0530SF/sfviper2')
t_interval_list, accel_3d_list, omega_3d_list = t_interval_list[45000:80000], accel_3d_list[45000:80000], omega_3d_list[45000:80000]
t_list = get_timelist(t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)
accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list[1000:], t_interval_list[1000:])

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list[1000:], velo_list, posi_list, t_list[1000:])

# %% [markdown]
# # 5.29 Rambling in CCS

# %%
t_interval_list, accel_3d_list, omega_3d_list = get_data('./../test0529/data3dCCSwalk2')
t_list = get_timelist(t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)
accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list[1000:], t_interval_list[1000:])

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list[1000:], velo_list, posi_list, t_list[1000:])

# %%
fig = plt.figure()
x = posi_list[:, 0]
y = posi_list[:, 1]
z = posi_list[:, 2]
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

ax = plt.axes(projection ='3d')
ax.plot3D(x, y, z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()

# %% [markdown]
# # 5.29 Xinyuan Jump
#
# Lifted up ~ 30 cm and put down 3 times, did not rotate.
#
# - The accelerometer probably mistook the acceleration to angular velocity

# %%
t_interval_list, accel_3d_list, omega_3d_list = get_data('./../test0529/data3dXinyuanJump0')
t_list = get_timelist(t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)
accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list[1000:], t_interval_list[1000:])

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list[1000:], velo_list, posi_list, t_list[1000:])

# %%
fig = plt.figure()
x = posi_list[:, 0]
y = posi_list[:, 1]
z = posi_list[:, 2]
plt.plot(x, y)
plt.show()

ax = plt.axes(projection ='3d')
ax.plot3D(x, y, z)
plt.show()

# %% [markdown]
# # 5.29 Xinyuan Rotate 1

# %%
t_interval_list, accel_3d_list, omega_3d_list = get_data('./../test0529/data3dXinyuanRotate1')
t_list = get_timelist(t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)
accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list[1000:], t_interval_list[1000:])

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list[1000:], velo_list, posi_list, t_list[1000:])

# %%
fig = plt.figure()
x = posi_list[:, 0]
y = posi_list[:, 1]
z = posi_list[:, 2]
plt.plot(x, y)
plt.show()

ax = plt.axes(projection ='3d')
ax.plot3D(x, y, z)
plt.show()

# %% [markdown]
# # 5.29 Xinyuan Rotate 2

# %%
t_interval_list, accel_3d_list, omega_3d_list = get_data('./../test0529/data3dXinyuanRotate0')
t_list = get_timelist(t_interval_list)
#euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)
accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list[1000:], t_interval_list[1000:])

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list[1000:], velo_list, posi_list, t_list[1000:])

# %%
fig = plt.figure()
x = posi_list[:, 0]
y = posi_list[:, 1]
z = posi_list[:, 2]
plt.plot(x, y)
plt.show()

ax = plt.axes(projection ='3d')
ax.plot3D(x, y, z)
plt.show()

# %% [markdown]
# # 5.27 Bus Test

# %%
data = np.genfromtxt('./../bikeTest/accelGyroLogBusTest.csv',delimiter=',')

# %%
accel_3d_list, omega_3d_list, t_interval_list = data[:, 1:4], data[:, 4:7], data[:, 0]
t_list = get_timelist(t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)

accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list, t_interval_list)

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list, velo_list, posi_list, t_list)

# %%
fig = plt.figure()
x = posi_list[:, 0]
y = posi_list[:, 1]
z = posi_list[:, 2]
plt.plot(x, y)
plt.show()

ax = plt.axes(projection ='3d')
ax.plot3D(x, y, z)
plt.show()

# %% [markdown]
# # 5.28 lift up, rotate, put back

# %%
data = np.genfromtxt('./../bikeTest/accelGyroLogUpDown0.csv',delimiter=',')

# %%
accel_3d_list, omega_3d_list, t_interval_list = data[:, 1:4], data[:, 4:7], data[:, 0]
t_list = get_timelist(t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)

accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list, t_interval_list)

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list, velo_list, posi_list, t_list)

# %%
fig = plt.figure()
x = posi_list[:5000, 0]
y = posi_list[:5000, 1]
z = posi_list[:5000, 2]
plt.plot(x, y)
plt.show()

ax = plt.axes(projection ='3d')
ax.plot3D(x, y, z)
plt.show()

# %% [markdown]
# # 5.28 Jichen ride bike home

# %%
data = np.genfromtxt('./../bikeTest/accelGyroLog05281407JichenBikeHome.csv',delimiter=',')

# %%
accel_3d_list, omega_3d_list, t_interval_list = data[:, 1:4], data[:, 4:7], data[:, 0]
t_list = get_timelist(t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)

accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list, t_interval_list)

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list, velo_list, posi_list, t_list)

# %%
fig = plt.figure()
x = posi_list[:, 0]
y = posi_list[:, 1]
z = posi_list[:, 2]
plt.plot(x, y)
plt.show()

ax = plt.axes(projection ='3d')
ax.plot3D(x, y, z)
plt.show()

# %% [markdown]
# # 5.23 Mysterious dataset

# %%
data = np.genfromtxt('./../testData0523/accelGyroLog82621763.csv',delimiter=',')

# %%
accel_3d_list, omega_3d_list, t_interval_list = data[:, 1:4], data[:, 4:7], data[:, 0]
t_list = get_timelist(t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)
accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list, t_interval_list)

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list, velo_list, posi_list, t_list)

# %% [markdown]
# # 5.18 mysterious data sets * 3

# %%
data = np.genfromtxt('./../testData0518/accelGyroLog4818878.csv',delimiter=',')

# %%
accel_3d_list, omega_3d_list, t_interval_list = data[:, 1:4], data[:, 4:7], data[:, 0]
t_list = get_timelist(t_interval_list)
euler, accel_3d_abs_list = get_3dAbsAccel_arhsComplicated(accel_3d_list, omega_3d_list, t_interval_list)

accel_3d_abs_calib_list,_ = calibrator3d(accel_3d_abs_list)
velo_list, posi_list = get_3dtraj(accel_3d_abs_calib_list, t_interval_list)

# %%
plot_3dAbsRotation(omega_3d_list, accel_3d_list, euler, accel_3d_abs_list, t_list)

# %%
plot_3dAccelVeloPosi(accel_3d_abs_calib_list, velo_list, posi_list, t_list)
