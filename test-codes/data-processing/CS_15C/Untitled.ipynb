# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
my_data = np.genfromtxt('D:/_xueXi/keCheng/2022S/PHYSCS15CExp/testData0511/accelXYZ14507849.csv',delimiter=',')

# %%
t_list = []
gravity_list = []
for index, t_interval in enumerate(my_data[:, 0]):
    t_list.append(sum(my_data[:index, 0]))
    gravity_list.append(np.sqrt(my_data[index,1]**2+my_data[index,2]**2+my_data[index,3]**2))

# %%
t_interval = my_data[:, 0]
accel_ax_list = my_data[:,1]
accel_ay_list = my_data[:,2]
accel_az_list = my_data[:,3]

# %%
plt.plot(t_list, gravity_list)
plt.show()

# %%
plt.plot(t_list, accel_ax_list)
plt.plot(t_list, accel_ay_list)
plt.plot(t_list, accel_az_list)
plt.show()
